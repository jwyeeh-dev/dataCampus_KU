# %%
# No-Free-Lunch :

# %%
# 데이터가 알고리즘보다 더 중요하다.

# %%
# Representative Learning : 차원의 저주, 정보 소실

# %%
from sklearn.datasets import load_digits

# %%
data = load_digits()

# %%
data.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
data.images
# Out:
# array([[[ 0.,  0.,  5., ...,  1.,  0.,  0.],
#         [ 0.,  0., 13., ..., 15.,  5.,  0.],
#         [ 0.,  3., 15., ..., 11.,  8.,  0.],
#         ...,
#         [ 0.,  4., 11., ..., 12.,  7.,  0.],
#         [ 0.,  2., 14., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  6., ...,  0.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ...,  5.,  0.,  0.],
#         [ 0.,  0.,  0., ...,  9.,  0.,  0.],
#         [ 0.,  0.,  3., ...,  6.,  0.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  3., ..., 14.,  0.,  0.],
#         [ 0.,  0.,  8., ..., 16.,  0.,  0.],
#         ...,
#         [ 0.,  9., 16., ...,  0.,  0.,  0.],
#         [ 0.,  3., 13., ..., 11.,  5.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.]],
#
#        ...,
#
#        [[ 0.,  0.,  1., ...,  1.,  0.,  0.],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# 실제 그 자체의 본질적인 값을 찾을 수 없기 때문에 Scaling을 진행한다. -> Feature Extraction

# %%
# Feature Extraction 보기. 헵스룰

# 그레디언트 베이스 러닝만 지원해주는게 아니기 때문에 러닝커브 어려움.

# %%
from sklearn.datasets import load_breast_cancer

# %%
breast = load_breast_cancer(as_frame=True)

# %%
breast.frame
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn.model_selection import learning_curve
from sklearn.neighbors import KNeighborsClassifier

# %%
learning_curve(KNeighborsClassifier(), breast.iloc)

# %%
# %pip install -U sklearn-evaluation
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 11.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 14.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn_evaluation

# %%
sklearn_evaluation.plot.learning_curve
# Re-substitution-evaluation

# %%
# Curse of Dimensionality 
# Feature Selection : Feature / Wrapper / Embedding

# %%
vars(dt)

# %%
# 트리에서 무질서도가 가장 낮은 상위 개체가 중요.

# %%
# Recursive Feature Elimination

# %% [markdown]
# # weight decay

# %%
# 오캄의 면도날 ;

# %% [markdown]
# # 구현하는 연습을 하자.

# %%
# 앙상블 -> 다른 특성의 모델을 제시한다.
# diminishing returns
# Co-relation, Co-variance -> 
# 오캄의 면도날(SVM) vs. 앙상블
# Bayesian 접근
# Cross-validation도 앙상블의 일종으로 볼 수 있다. 
# Overfittinf 감소 : Stabilizer, 
# 마냥 좋지만은 않을 수 있다 배깅. -> 시행착오.

# SVM, 랜덤 포레스트

# list of tuple -> 

# Voting -> 0dlf ghkrfbf, 
# 리그레션, 소프트맥스 -> 실무에서 활용하지 않는다. 
# numerical stability 위반 -> 따라서, from_logits를 사용해서 리그레션처럼 활용한다. 보팅 안쓴다. 
# 알고리즘상 기준적으로 규정되어 있는 모델이 아니라면. predict_proba

# log_proba -> 오즈비 계산.
# decision function -> 왜 0으로 선택했는지. 
# lr schedule -> 
# LGBM, XGBoost, 카타

# Stacking 기법 :

# %%
# %pip install -U ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.0/353.0 kB 8.4 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.2 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 649.9/649.9 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 21.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 30.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 26.6 MB/s eta 0:00:00a 0:00:01
# ...
